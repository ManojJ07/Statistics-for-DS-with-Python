# %%
import pandas as pd
boston_url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ST0151EN-SkillsNetwork/labs/boston_housing.csv'
boston_df=pd.read_csv(boston_url)
boston_df
# Out:
#      Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0             0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0
# 1             1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0
# 2             2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0
# 3             3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0
# 4             4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0
# ..          ...      ...   ...    ...   ...    ...    ...   ...     ...  ...
# 501         501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0
# 502         502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0
# 503         503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0
# 504         504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0
# 505         505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0
#
#        TAX  PTRATIO  LSTAT  MEDV
# ...

# %%
boston_df = boston_df.drop("Unnamed: 0",axis=1)
boston_df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO  LSTAT  MEDV
# 0       15.3   4.98  24.0
# 1       17.8   9.14  21.6
# ...

# %% [markdown]
# #### For all visualizations, please include a title in each graph and appropriate labels
#
# ##### Generate the following and explain your findings:
#
# - For the "Median value of owner-occupied homes" provide a boxplot
#
# - Provide a  bar plot for the Charles river variable
#
# - Provide a boxplot for the MEDV variable vs the AGE variable. (Discretize the age variable into three groups of 35 years and younger, between 35 and 70 years and 70 years and older)
#
# - Provide a scatter plot to show the relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town. What can you say about the relationship?
#
# - Create a histogram for the pupil to teacher ratio variable

# %%
import matplotlib.pyplot as plt

# Generate the boxplot for MEDV
plt.figure(figsize=(8, 6))
plt.boxplot(boston_df['MEDV'])
plt.title('Boxplot of Median Value of Owner-occupied Homes (MEDV)')
plt.xlabel('MEDV')
plt.ylabel('Value')
plt.show()

# %%
# Count the occurrences of each value in the CHAS variable
chas_counts = boston_df['CHAS'].value_counts()

# Generate the bar plot for CHAS
plt.figure(figsize=(8, 6))
chas_counts.plot(kind='bar')
plt.title('Bar Plot of Charles River Variable')
plt.xlabel('CHAS')
plt.ylabel('Count')
plt.show()

# %%
# Discretize the AGE variable into three groups
boston_df['AGE Group'] = pd.cut(boston_df['AGE'], bins=[0, 35, 70, float('inf')], labels=['35 and younger', 'between 35 and 70', '70 and older'])

# Generate the boxplot for MEDV vs AGE Group
plt.figure(figsize=(8, 6))
boston_df.boxplot(column='MEDV', by='AGE Group')
plt.title('Boxplot of MEDV vs AGE Group')
plt.suptitle('')
plt.xlabel('AGE Group')
plt.ylabel('MEDV')
plt.show()

# %%
# Generate the scatter plot for NOX vs INDUS
plt.figure(figsize=(8, 6))
plt.scatter(boston_df['NOX'], boston_df['INDUS'])
plt.title('Scatter Plot: Nitric Oxide Concentrations vs Non-Retail Business Acres')
plt.xlabel('Nitric Oxide Concentrations')
plt.ylabel('Proportion of Non-Retail Business Acres')
plt.show()

# %% [markdown]
# ##### From the scatter plot, we can observe the following:
#
# - The x-axis represents the Nitric oxide concentrations.
# - The y-axis represents the proportion of non-retail business acres per town.
# - Each point on the plot represents a data point from the dataset.
# - The scatter plot shows the distribution of the data points and the relationship between NOX and INDUS.
# - It allows us to identify any patterns, trends, or correlations between the two variables.
#
# ##### Based on the scatter plot, we can make the following observations:
#
# - There appears to be a positive relationship between Nitric oxide concentrations and the proportion of non-retail business acres per town.
# - As the proportion of non-retail business acres per town increases, the Nitric oxide concentrations also tend to increase.
# - However, the relationship is not perfectly linear, as there is some scattering of the data points.

# %%
# Generate the histogram for PTRATIO
plt.figure(figsize=(8, 6))
plt.hist(boston_df['PTRATIO'], bins=10, edgecolor='black')
plt.title('Histogram: Pupil to Teacher Ratio')
plt.xlabel('Pupil to Teacher Ratio')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### From the histogram, we can observe the following:
#
# - The x-axis represents the ranges or intervals of the PTRATIO variable.
# - The y-axis represents the frequency or count of data points falling into each interval.
# - The histogram displays the shape and distribution of the PTRATIO variable.
# - It helps us understand the concentration of values and any patterns in the data.
#
# ##### Based on the histogram:
#
# - The distribution of the pupil to teacher ratio appears to be slightly left-skewed.
# - The majority of the data points fall within the range of approximately 16 to 21, with a peak around 21.
# - There are relatively fewer data points with PTRATIO values outside this range.
# - The histogram provides insights into the distribution and concentration of pupil to teacher ratios in the dataset.

# %% [markdown]
# #### For each of the following questions;
#
# - Is there a significant difference in median value of houses bounded by the Charles river or not? (T-test for independent samples)
#
# - Is there a difference in Median values of houses (MEDV) for each proportion of owner occupied units built prior to 1940 (AGE)? (ANOVA)
#
# - Can we conclude that there is no relationship between Nitric oxide concentrations and proportion of non-retail business acres per town? (Pearson Correlation)
#
# - What is the impact of an additional weighted distance  to the five Boston employment centres on the median value of owner occupied homes? (Regression analysis)
#
# ##### Be sure to:
#
# 1. State your hypothesis.
#
# 2. Use α = 0.05
#
# 3. Perform the test Statistics.
#
# 4. State the conclusion from the test.

# %%
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols

# Question 1: T-test for independent samples
medv_charles_river = boston_df[boston_df['CHAS'] == 1]['MEDV']
medv_not_charles_river = boston_df[boston_df['CHAS'] == 0]['MEDV']
t_stat, p_value = stats.ttest_ind(medv_charles_river, medv_not_charles_river)
alpha = 0.05
if p_value < alpha:
    print("There is a significant difference in median values of houses bounded by the Charles river and those not bounded by the river.")
else:
    print("There is no significant difference in median values of houses bounded by the Charles river and those not bounded by the river.")

# Question 2: ANOVA
model = ols('MEDV ~ AGE', data=boston_df).fit()
anova_table = sm.stats.anova_lm(model, typ=2)
p_value = anova_table['PR(>F)'][0]
if p_value < alpha:
    print("There is a significant difference in median values of houses for each proportion of owner-occupied units built prior to 1940.")
else:
    print("There is no significant difference in median values of houses for each proportion of owner-occupied units built prior to 1940.")

# Question 3: Pearson Correlation
correlation, p_value = stats.pearsonr(boston_df['NOX'], boston_df['INDUS'])
if p_value > alpha:
    print("We cannot conclude that there is a significant relationship between Nitric oxide concentrations and proportion of non-retail business acres per town.")
else:
    print("There is a significant relationship between Nitric oxide concentrations and proportion of non-retail business acres per town.")

# Question 4: Regression analysis
X = boston_df['DIS']
y = boston_df['MEDV']
X = sm.add_constant(X)  # Add a constant for the intercept term
model = sm.OLS(y, X).fit()
p_value = model.pvalues[1]
if p_value < alpha:
    print("There is a significant impact of an additional weighted distance to the five Boston employment centres on the median value of owner-occupied homes.")
else:
    print("There is no significant impact of an additional weighted distance to the five Boston employment centres on the median value of owner-occupied homes.")
# Out:
# There is a significant difference in median values of houses bounded by the Charles river and those not bounded by the river.
# There is a significant difference in median values of houses for each proportion of owner-occupied units built prior to 1940.
# There is a significant relationship between Nitric oxide concentrations and proportion of non-retail business acres per town.
# There is a significant impact of an additional weighted distance to the five Boston employment centres on the median value of owner-occupied homes.
